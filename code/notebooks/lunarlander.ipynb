# %% [markdown]
# #

# %%
import gymnasium as gym

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import (
    notebook_login,
)  # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

from wandb.integration.sb3 import WandbCallback

# %%
env = make_vec_env("LunarLander-v3", n_envs=16)
model = PPO(
    policy= "MlpPolicy",
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda=0.98,
    ent_coef = 0.01,
    verbose = 1,
)
model.learn(total_timesteps=int(10e5))
model_name = "ppo-LunarLander-v3"
model.save(model_name)
# Out:
# /Users/frankcholula/Workspace/school/FRL-playground/.venv/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.2     |
# |    ep_rew_mean     | -179     |
# | time/              |          |
# |    fps             | 10707    |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 16384    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.2         |
# |    ep_rew_mean          | -145         |
# | time/                   |              |
# |    fps                  | 7488         |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0057793134 |
# |    clip_fraction        | 0.054        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.000936    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.76e+03     |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.00499     |
# |    value_loss           | 4.86e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96          |
# |    ep_rew_mean          | -134        |
# | time/                   |             |
# |    fps                  | 6740        |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007814808 |
# |    clip_fraction        | 0.0182      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00366    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 601         |
# |    n_updates            | 8           |
# |    policy_gradient_loss | -0.00348    |
# |    value_loss           | 2.12e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 103          |
# |    ep_rew_mean          | -135         |
# | time/                   |              |
# |    fps                  | 6417         |
# |    iterations           | 4            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0075539825 |
# |    clip_fraction        | 0.0433       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00138     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 347          |
# |    n_updates            | 12           |
# |    policy_gradient_loss | -0.00543     |
# |    value_loss           | 1.32e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.7        |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 6221        |
# |    iterations           | 5           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009264177 |
# |    clip_fraction        | 0.0978      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.000226    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 568         |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.00451    |
# |    value_loss           | 1.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.1        |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 6100        |
# |    iterations           | 6           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.007147069 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.000218   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 223         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0029     |
# |    value_loss           | 689         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 101        |
# |    ep_rew_mean          | -81.5      |
# | time/                   |            |
# |    fps                  | 6026       |
# |    iterations           | 7          |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.00857127 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | -0.000591  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 227        |
# |    n_updates            | 24         |
# |    policy_gradient_loss | -0.00641   |
# |    value_loss           | 595        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | -75.5       |
# | time/                   |             |
# |    fps                  | 5953        |
# |    iterations           | 8           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.009521563 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.012      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 119         |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.0042     |
# |    value_loss           | 364         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -57.2       |
# | time/                   |             |
# |    fps                  | 5889        |
# |    iterations           | 9           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.011381565 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | -0.000103   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 194         |
# |    n_updates            | 32          |
# |    policy_gradient_loss | -0.00871    |
# |    value_loss           | 368         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 111         |
# |    ep_rew_mean          | -45.9       |
# | time/                   |             |
# |    fps                  | 5737        |
# |    iterations           | 10          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.009214184 |
# |    clip_fraction        | 0.0717      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | -0.000128   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 276         |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.00553    |
# |    value_loss           | 452         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 122         |
# |    ep_rew_mean          | -26.2       |
# | time/                   |             |
# |    fps                  | 5675        |
# |    iterations           | 11          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.008086281 |
# |    clip_fraction        | 0.0535      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.000104    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 130         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00381    |
# |    value_loss           | 400         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 120          |
# |    ep_rew_mean          | -30.2        |
# | time/                   |              |
# |    fps                  | 5436         |
# |    iterations           | 12           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0048788176 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | -7.56e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 222          |
# |    n_updates            | 44           |
# |    policy_gradient_loss | -0.000724    |
# |    value_loss           | 452          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 159         |
# |    ep_rew_mean          | -18.9       |
# | time/                   |             |
# |    fps                  | 5019        |
# |    iterations           | 13          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.009217184 |
# |    clip_fraction        | 0.0758      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 2.86e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 249         |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.00604    |
# |    value_loss           | 486         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 196         |
# |    ep_rew_mean          | -9          |
# | time/                   |             |
# |    fps                  | 4516        |
# |    iterations           | 14          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.005359759 |
# |    clip_fraction        | 0.0393      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | -0.000205   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 361         |
# |    n_updates            | 52          |
# |    policy_gradient_loss | -0.00246    |
# |    value_loss           | 584         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 260          |
# |    ep_rew_mean          | -7.39        |
# | time/                   |              |
# |    fps                  | 4123         |
# |    iterations           | 15           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0040616617 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | -0.00306     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 360          |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00197     |
# |    value_loss           | 532          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -1.56        |
# | time/                   |              |
# |    fps                  | 3808         |
# |    iterations           | 16           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0060552475 |
# |    clip_fraction        | 0.00757      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.0985       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 188          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 554          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 311         |
# |    ep_rew_mean          | 4.04        |
# | time/                   |             |
# |    fps                  | 3486        |
# |    iterations           | 17          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.005158074 |
# |    clip_fraction        | 0.0239      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 173         |
# |    n_updates            | 64          |
# |    policy_gradient_loss | -0.00115    |
# |    value_loss           | 368         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 397         |
# |    ep_rew_mean          | 14.3        |
# | time/                   |             |
# |    fps                  | 3201        |
# |    iterations           | 18          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.005389996 |
# |    clip_fraction        | 0.0604      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.606       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 194         |
# |    n_updates            | 68          |
# |    policy_gradient_loss | -0.00161    |
# |    value_loss           | 261         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 496        |
# |    ep_rew_mean          | 20.9       |
# | time/                   |            |
# |    fps                  | 2993       |
# |    iterations           | 19         |
# |    time_elapsed         | 103        |
# |    total_timesteps      | 311296     |
# | train/                  |            |
# |    approx_kl            | 0.00841938 |
# |    clip_fraction        | 0.0819     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.22      |
# |    explained_variance   | 0.721      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 55.7       |
# |    n_updates            | 72         |
# |    policy_gradient_loss | -0.00396   |
# |    value_loss           | 186        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 576         |
# |    ep_rew_mean          | 34          |
# | time/                   |             |
# |    fps                  | 2818        |
# |    iterations           | 20          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.004841578 |
# |    clip_fraction        | 0.0271      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 95.8        |
# |    n_updates            | 76          |
# |    policy_gradient_loss | -0.00111    |
# |    value_loss           | 183         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 603          |
# |    ep_rew_mean          | 33.7         |
# | time/                   |              |
# |    fps                  | 2689         |
# |    iterations           | 21           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0062741525 |
# |    clip_fraction        | 0.0583       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.842        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 54.5         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00303     |
# |    value_loss           | 130          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 663          |
# |    ep_rew_mean          | 46.5         |
# | time/                   |              |
# |    fps                  | 2569         |
# |    iterations           | 22           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0067564417 |
# |    clip_fraction        | 0.0553       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.846        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.3         |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 139          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 715         |
# |    ep_rew_mean          | 56.7        |
# | time/                   |             |
# |    fps                  | 2473        |
# |    iterations           | 23          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.006769665 |
# |    clip_fraction        | 0.0562      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.6        |
# |    n_updates            | 88          |
# |    policy_gradient_loss | -0.0016     |
# |    value_loss           | 70.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 777         |
# |    ep_rew_mean          | 68.5        |
# | time/                   |             |
# |    fps                  | 2386        |
# |    iterations           | 24          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.005701212 |
# |    clip_fraction        | 0.0632      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.3        |
# |    n_updates            | 92          |
# |    policy_gradient_loss | -0.00384    |
# |    value_loss           | 67.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 805         |
# |    ep_rew_mean          | 73.9        |
# | time/                   |             |
# |    fps                  | 2323        |
# |    iterations           | 25          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.004392345 |
# |    clip_fraction        | 0.0319      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.9        |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.00165    |
# |    value_loss           | 72.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 861         |
# |    ep_rew_mean          | 89.6        |
# | time/                   |             |
# |    fps                  | 2279        |
# |    iterations           | 26          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.004195156 |
# |    clip_fraction        | 0.034       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.1        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.000838   |
# |    value_loss           | 49.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 870         |
# |    ep_rew_mean          | 93.6        |
# | time/                   |             |
# |    fps                  | 2244        |
# |    iterations           | 27          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.005038065 |
# |    clip_fraction        | 0.0343      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.1        |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.00094    |
# |    value_loss           | 58.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 811         |
# |    ep_rew_mean          | 93.8        |
# | time/                   |             |
# |    fps                  | 2208        |
# |    iterations           | 28          |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.006817871 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 74.9        |
# |    n_updates            | 108         |
# |    policy_gradient_loss | -0.0016     |
# |    value_loss           | 81.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 784          |
# |    ep_rew_mean          | 97.9         |
# | time/                   |              |
# |    fps                  | 2174         |
# |    iterations           | 29           |
# |    time_elapsed         | 218          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0061639976 |
# |    clip_fraction        | 0.026        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.907        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41           |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 133          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 773          |
# |    ep_rew_mean          | 99.9         |
# | time/                   |              |
# |    fps                  | 2135         |
# |    iterations           | 30           |
# |    time_elapsed         | 230          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0042110085 |
# |    clip_fraction        | 0.0422       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.894        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 164          |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 126          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 756         |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 2108        |
# |    iterations           | 31          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.004418944 |
# |    clip_fraction        | 0.0295      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.7        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.000379   |
# |    value_loss           | 94.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 764          |
# |    ep_rew_mean          | 104          |
# | time/                   |              |
# |    fps                  | 2087         |
# |    iterations           | 32           |
# |    time_elapsed         | 251          |
# |    total_timesteps      | 524288       |
# | train/                  |              |
# |    approx_kl            | 0.0036086603 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.94         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.71         |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.000815    |
# |    value_loss           | 68.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 797         |
# |    ep_rew_mean          | 110         |
# | time/                   |             |
# |    fps                  | 2059        |
# |    iterations           | 33          |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 540672      |
# | train/                  |             |
# |    approx_kl            | 0.004450448 |
# |    clip_fraction        | 0.0219      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.55        |
# |    n_updates            | 128         |
# |    policy_gradient_loss | -0.00198    |
# |    value_loss           | 56.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 838          |
# |    ep_rew_mean          | 119          |
# | time/                   |              |
# |    fps                  | 2034         |
# |    iterations           | 34           |
# |    time_elapsed         | 273          |
# |    total_timesteps      | 557056       |
# | train/                  |              |
# |    approx_kl            | 0.0030727736 |
# |    clip_fraction        | 0.0191       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.956        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.92         |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -0.000653    |
# |    value_loss           | 51.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 833          |
# |    ep_rew_mean          | 118          |
# | time/                   |              |
# |    fps                  | 2018         |
# |    iterations           | 35           |
# |    time_elapsed         | 284          |
# |    total_timesteps      | 573440       |
# | train/                  |              |
# |    approx_kl            | 0.0068707406 |
# |    clip_fraction        | 0.0387       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.53         |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 27.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 812          |
# |    ep_rew_mean          | 120          |
# | time/                   |              |
# |    fps                  | 2007         |
# |    iterations           | 36           |
# |    time_elapsed         | 293          |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0041946564 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.996       |
# |    explained_variance   | 0.932        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 111          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000469    |
# |    value_loss           | 77.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 823         |
# |    ep_rew_mean          | 123         |
# | time/                   |             |
# |    fps                  | 1991        |
# |    iterations           | 37          |
# |    time_elapsed         | 304         |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.003831448 |
# |    clip_fraction        | 0.0212      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35          |
# |    n_updates            | 144         |
# |    policy_gradient_loss | -0.000793   |
# |    value_loss           | 92.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 847          |
# |    ep_rew_mean          | 128          |
# | time/                   |              |
# |    fps                  | 1974         |
# |    iterations           | 38           |
# |    time_elapsed         | 315          |
# |    total_timesteps      | 622592       |
# | train/                  |              |
# |    approx_kl            | 0.0046251863 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.998       |
# |    explained_variance   | 0.931        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77.9         |
# |    n_updates            | 148          |
# |    policy_gradient_loss | -0.000775    |
# |    value_loss           | 91.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 862          |
# |    ep_rew_mean          | 132          |
# | time/                   |              |
# |    fps                  | 1959         |
# |    iterations           | 39           |
# |    time_elapsed         | 326          |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 0.0040835375 |
# |    clip_fraction        | 0.0395       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.985       |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.2         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -0.00116     |
# |    value_loss           | 18.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 862         |
# |    ep_rew_mean          | 130         |
# | time/                   |             |
# |    fps                  | 1945        |
# |    iterations           | 40          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.005206761 |
# |    clip_fraction        | 0.0434      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.978      |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.5        |
# |    n_updates            | 156         |
# |    policy_gradient_loss | -0.000964   |
# |    value_loss           | 15          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | 140          |
# | time/                   |              |
# |    fps                  | 1933         |
# |    iterations           | 41           |
# |    time_elapsed         | 347          |
# |    total_timesteps      | 671744       |
# | train/                  |              |
# |    approx_kl            | 0.0038354266 |
# |    clip_fraction        | 0.0392       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.19         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000464    |
# |    value_loss           | 21.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 924         |
# |    ep_rew_mean          | 140         |
# | time/                   |             |
# |    fps                  | 1921        |
# |    iterations           | 42          |
# |    time_elapsed         | 358         |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.005737837 |
# |    clip_fraction        | 0.0191      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.991      |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.78        |
# |    n_updates            | 164         |
# |    policy_gradient_loss | -0.000342   |
# |    value_loss           | 26          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 953        |
# |    ep_rew_mean          | 143        |
# | time/                   |            |
# |    fps                  | 1912       |
# |    iterations           | 43         |
# |    time_elapsed         | 368        |
# |    total_timesteps      | 704512     |
# | train/                  |            |
# |    approx_kl            | 0.00449212 |
# |    clip_fraction        | 0.0353     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.99      |
# |    explained_variance   | 0.988      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.33       |
# |    n_updates            | 168        |
# |    policy_gradient_loss | -2.62e-07  |
# |    value_loss           | 11.9       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 921          |
# |    ep_rew_mean          | 140          |
# | time/                   |              |
# |    fps                  | 1905         |
# |    iterations           | 44           |
# |    time_elapsed         | 378          |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0042875772 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.969       |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.5         |
# |    n_updates            | 172          |
# |    policy_gradient_loss | -0.000842    |
# |    value_loss           | 22.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 929          |
# |    ep_rew_mean          | 143          |
# | time/                   |              |
# |    fps                  | 1896         |
# |    iterations           | 45           |
# |    time_elapsed         | 388          |
# |    total_timesteps      | 737280       |
# | train/                  |              |
# |    approx_kl            | 0.0043095797 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.944       |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14           |
# |    n_updates            | 176          |
# |    policy_gradient_loss | -0.000452    |
# |    value_loss           | 43.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 913         |
# |    ep_rew_mean          | 142         |
# | time/                   |             |
# |    fps                  | 1891        |
# |    iterations           | 46          |
# |    time_elapsed         | 398         |
# |    total_timesteps      | 753664      |
# | train/                  |             |
# |    approx_kl            | 0.004958188 |
# |    clip_fraction        | 0.0372      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.946      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.9         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00158    |
# |    value_loss           | 22.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 929          |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 1885         |
# |    iterations           | 47           |
# |    time_elapsed         | 408          |
# |    total_timesteps      | 770048       |
# | train/                  |              |
# |    approx_kl            | 0.0049425857 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.935       |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.83         |
# |    n_updates            | 184          |
# |    policy_gradient_loss | 0.000156     |
# |    value_loss           | 28           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 918          |
# |    ep_rew_mean          | 146          |
# | time/                   |              |
# |    fps                  | 1881         |
# |    iterations           | 48           |
# |    time_elapsed         | 417          |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0057205567 |
# |    clip_fraction        | 0.0649       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.899       |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.66         |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.0014      |
# |    value_loss           | 5.16         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 909         |
# |    ep_rew_mean          | 147         |
# | time/                   |             |
# |    fps                  | 1878        |
# |    iterations           | 49          |
# |    time_elapsed         | 427         |
# |    total_timesteps      | 802816      |
# | train/                  |             |
# |    approx_kl            | 0.002667028 |
# |    clip_fraction        | 0.0188      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.902      |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.1        |
# |    n_updates            | 192         |
# |    policy_gradient_loss | -0.000401   |
# |    value_loss           | 53.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 909         |
# |    ep_rew_mean          | 146         |
# | time/                   |             |
# |    fps                  | 1873        |
# |    iterations           | 50          |
# |    time_elapsed         | 437         |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.004672972 |
# |    clip_fraction        | 0.0434      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.895      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.15        |
# |    n_updates            | 196         |
# |    policy_gradient_loss | -0.000391   |
# |    value_loss           | 15.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 925          |
# |    ep_rew_mean          | 150          |
# | time/                   |              |
# |    fps                  | 1870         |
# |    iterations           | 51           |
# |    time_elapsed         | 446          |
# |    total_timesteps      | 835584       |
# | train/                  |              |
# |    approx_kl            | 0.0025276027 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.878       |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.47         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 49.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 924          |
# |    ep_rew_mean          | 152          |
# | time/                   |              |
# |    fps                  | 1864         |
# |    iterations           | 52           |
# |    time_elapsed         | 456          |
# |    total_timesteps      | 851968       |
# | train/                  |              |
# |    approx_kl            | 0.0035722908 |
# |    clip_fraction        | 0.0481       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.915       |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.71         |
# |    n_updates            | 204          |
# |    policy_gradient_loss | -0.000533    |
# |    value_loss           | 24.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 926         |
# |    ep_rew_mean          | 152         |
# | time/                   |             |
# |    fps                  | 1861        |
# |    iterations           | 53          |
# |    time_elapsed         | 466         |
# |    total_timesteps      | 868352      |
# | train/                  |             |
# |    approx_kl            | 0.004477663 |
# |    clip_fraction        | 0.0413      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.863      |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.23        |
# |    n_updates            | 208         |
# |    policy_gradient_loss | -0.000272   |
# |    value_loss           | 37.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 935         |
# |    ep_rew_mean          | 154         |
# | time/                   |             |
# |    fps                  | 1860        |
# |    iterations           | 54          |
# |    time_elapsed         | 475         |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.003533893 |
# |    clip_fraction        | 0.0368      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04        |
# |    n_updates            | 212         |
# |    policy_gradient_loss | -0.000447   |
# |    value_loss           | 2.82        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 895          |
# |    ep_rew_mean          | 152          |
# | time/                   |              |
# |    fps                  | 1861         |
# |    iterations           | 55           |
# |    time_elapsed         | 484          |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# |    approx_kl            | 0.0051579745 |
# |    clip_fraction        | 0.0252       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.828       |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44           |
# |    n_updates            | 216          |
# |    policy_gradient_loss | -0.000778    |
# |    value_loss           | 42.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 905          |
# |    ep_rew_mean          | 160          |
# | time/                   |              |
# |    fps                  | 1863         |
# |    iterations           | 56           |
# |    time_elapsed         | 492          |
# |    total_timesteps      | 917504       |
# | train/                  |              |
# |    approx_kl            | 0.0063735517 |
# |    clip_fraction        | 0.0669       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.75        |
# |    explained_variance   | 0.919        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.7         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00252     |
# |    value_loss           | 143          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 859          |
# |    ep_rew_mean          | 173          |
# | time/                   |              |
# |    fps                  | 1865         |
# |    iterations           | 57           |
# |    time_elapsed         | 500          |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0038146637 |
# |    clip_fraction        | 0.0457       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.716       |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.68         |
# |    n_updates            | 224          |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 65.6         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 761        |
# |    ep_rew_mean          | 193        |
# | time/                   |            |
# |    fps                  | 1869       |
# |    iterations           | 58         |
# |    time_elapsed         | 508        |
# |    total_timesteps      | 950272     |
# | train/                  |            |
# |    approx_kl            | 0.00570444 |
# |    clip_fraction        | 0.0628     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.647     |
# |    explained_variance   | 0.896      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 68.6       |
# |    n_updates            | 228        |
# |    policy_gradient_loss | -0.00321   |
# |    value_loss           | 204        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 606         |
# |    ep_rew_mean          | 222         |
# | time/                   |             |
# |    fps                  | 1878        |
# |    iterations           | 59          |
# |    time_elapsed         | 514         |
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.004804725 |
# |    clip_fraction        | 0.0685      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.671      |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 167         |
# |    n_updates            | 232         |
# |    policy_gradient_loss | -0.00313    |
# |    value_loss           | 299         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 440         |
# |    ep_rew_mean          | 238         |
# | time/                   |             |
# |    fps                  | 1887        |
# |    iterations           | 60          |
# |    time_elapsed         | 520         |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.006134922 |
# |    clip_fraction        | 0.063       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.662      |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 110         |
# |    n_updates            | 236         |
# |    policy_gradient_loss | -0.00333    |
# |    value_loss           | 372         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 1899        |
# |    iterations           | 61          |
# |    time_elapsed         | 526         |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.004577967 |
# |    clip_fraction        | 0.0425      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.65       |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64          |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0024     |
# |    value_loss           | 284         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 302          |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 1912         |
# |    iterations           | 62           |
# |    time_elapsed         | 531          |
# |    total_timesteps      | 1015808      |
# | train/                  |              |
# |    approx_kl            | 0.0048214793 |
# |    clip_fraction        | 0.0476       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.718       |
# |    explained_variance   | 0.79         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 171          |
# |    n_updates            | 244          |
# |    policy_gradient_loss | -0.00127     |
# |    value_loss           | 308          |
# ------------------------------------------

# %%
model_name = "ppo-LunarLander-v3"
eval_env = Monitor(gym.make("LunarLander-v3", render_mode="human"))
model = PPO.load(model_name, env=eval_env)
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic= True)
print(f"Mean reward: {mean_reward} +/- {std_reward}")
# Out:
# Wrapping the env in a DummyVecEnv.
# 2025-06-20 15:28:54.890 python[53389:2281315] TSM AdjustCapsLockLEDForKeyTransitionHandling - _ISSetPhysicalKeyboardCapsLockLED Inhibit
# Mean reward: 264.83670570000004 +/- 16.170327888668062
